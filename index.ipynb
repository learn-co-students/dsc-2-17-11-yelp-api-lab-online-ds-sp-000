# %% [markdown]
# # Yelp API - Lab
#
# The previously deployed lab on working around building a GIS with Yelp API and Folium can be found [here](https://github.com/learn-co-curriculum/dsc-2-15-10-yelp-api-gis-lab/tree/a56358c2d0c2daf569a5f50937c4c27463aadb1a) (not relevant for new students).
#
#
# ## Introduction
#
# Now that we've seen how the Yelp API works, and some basic Folium visualizations its time to put those skills to work in order to create a working map! Taking things a step further, you'll also independently explore how to perform pagination in order to retrieve a full results set from the Yelp API!
#
# ## Objectives
#
# You will be able to:
# * Create HTTP requests to get data from Yelp API
# * Parse HTTP responses and perform data analysis on the data returned
# * Perform pagination to retrieve troves of data!
# * Create a simple geographical system on to view information about selected businesses, at a given location.

# %% [markdown]
# ## Problem Introduction
#
# You've now worked with some API calls, but we have yet to see how to retrieve a more complete dataset in a programmatic manner. Returning to the Yelp API, the [documentation](https://www.yelp.com/developers/documentation/v3/business_search) also provides us details regarding the API limits. These often include details about the number of requests a user is allowed to make within a specified time limit and the maximum number of results to be returned. In this case, we are told that any request has a maximum of 50 results per request and defaults to 20. Furthermore, any search will be limited to a total of 1000 results. To retrieve all 1000 of these results, we would have to page through the results piece by piece, retriving 50 at a time. Processes such as these are often refered to as pagination.
#
# In this lab, you will define a search and then paginate over the results to retrieve all of the results. You'll then parse these responses as a DataFrame (for further exploration) and create a map using Folium to visualize the results geographically.

# %% [markdown]
# ## Part I - Make the Initial Request
#
# Start by making an initial request to the Yelp API. Your search must include at least 2 parameters: **term** and **location**. For example, you might search for pizza restaurants in NYC. The term and location is up to you, but make the request below.

# %%
#Your code here
#'tKntTkL12un_MRxa4uShMA'
import requests
api_key ='v0BFwL3fT7YfEVlCiupGtpDQQaeOsUe4DKjHfFZkIS0ZYiNJwM-LF9MR7Fo6erWCi28mVIpENCFb2V0t4HmQi90ys_-jgGZBiQd3kQm4X7BvEbgZHKkPbKo3miEdXXYx'


term = 'Indian'
location = 'The Woodlands TX'
SEARCH_LIMIT = 10

url = 'https://api.yelp.com/v3/businesses/search'

headers = {
        'Authorization': 'Bearer {}'.format(api_key),
    }

url_params = {
                'term': term.replace(' ', '+'),
                'location': location.replace(' ', '+'),
                'limit': SEARCH_LIMIT
            }
response = requests.get(url, headers=headers, params=url_params)
print(response)
print(type(response.text))
print(response.text[:1000])
# Out:
# <Response [200]>
# <class 'str'>
# {"businesses": [{"id": "CoIm7M7QaPHXEs5LpjH06g", "alias": "hyderabad-house-the-woodlands", "name": "Hyderabad House", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/fD-P7GnO9TOpAKv-NHiYlA/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/hyderabad-house-the-woodlands?adjust_creative=tKntTkL12un_MRxa4uShMA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=tKntTkL12un_MRxa4uShMA", "review_count": 162, "categories": [{"alias": "indpak", "title": "Indian"}], "rating": 3.5, "coordinates": {"latitude": 30.1265751, "longitude": -95.4480616}, "transactions": ["delivery", "pickup"], "price": "$$", "location": {"address1": "407 Sawdust Rd", "address2": null, "address3": "", "city": "The Woodlands", "zip_code": "77380", "country": "US", "state": "TX", "display_address": ["407 Sawdust Rd", "The Woodlands, TX 77380"]}, "phone": "+12812035020", "display_phone": "(281) 203-5020", "distance": 5554.975358081575}, {"id": "yGc0I0S-MHZtspmlW8b2hQ", "alias": "palette-i

# %% [markdown]
# ## Pagination
#
# Now that you have an initial response, you can examine the contents of the json container. For example, you might start with ```response.josn().keys()```. Here, you'll see a key for `'total'`, which tells you the full number of matching results given your query parameters. Write a loop (or ideally a function) which then makes successive API calls using the offset parameter to retrieve all of the results (or 5000 for a particularly large result set) for the original query. As you do this, be mindful of how you store the data. Your final goal will be to reformat the data concerning the businesses themselves into a pandas DataFrame from the json objects.
#
# **Note: be mindful of the API rate limits. You can only make 5000 requests per day, and are also can make requests too fast. Start prototyping small before running a loop that could be faulty. You can also use time.sleep(n) to add delays. For more details see https://www.yelp.com/developers/documentation/v3/rate_limiting.**

# %%
# Your code here; use a function or loop to retrieve all the results from your original request
response.json().keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
for key in response.json().keys():
    print(key)
    value = response.json()[key] #Use standard dictionary formatting
    print(type(value)) #What type is it?
    print('\n\n') #Seperate out data
# Out:
# businesses
# <class 'list'>
#
#
#
# total
# <class 'int'>
#
#
#
# region
# <class 'dict'>

# %%
response.json()['businesses']
# Out:
# [{'id': 'CoIm7M7QaPHXEs5LpjH06g',
#   'alias': 'hyderabad-house-the-woodlands',
#   'name': 'Hyderabad House',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fD-P7GnO9TOpAKv-NHiYlA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/hyderabad-house-the-woodlands?adjust_creative=tKntTkL12un_MRxa4uShMA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=tKntTkL12un_MRxa4uShMA',
#   'review_count': 162,
#   'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 30.1265751, 'longitude': -95.4480616},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '407 Sawdust Rd',
#    'address2': None,
#    'address3': '',
#    'city': 'The Woodlands',
#    'zip_code': '77380',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['407 Sawdust Rd', 'The Woodlands, TX 77380']},
#   'phone': '+12812035020',
#   'display_phone': '(281) 203-5020',
#   'distance': 5554.975358081575},
#  {'id': 'yGc0I0S-MHZtspmlW8b2hQ',
#   'alias': 'palette-indian-kitchen-spring',
#   'name': 'Palette Indian Kitchen',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/qm4Cs-A3_V8gORoMOYSAPw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/palette-indian-kitchen-spring?adjust_creative=tKntTkL12un_MRxa4uShMA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=tKntTkL12un_MRxa4uShMA',
#   'review_count': 247,
#   'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 30.1076513, 'longitude': -95.3851471},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '3559 Rayford Rd',
#    'address2': 'Ste 200',
#    'address3': None,
#    'city': 'Spring',
#    'zip_code': '77386',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['3559 Rayford Rd', 'Ste 200', 'Spring, TX 77386']},
#   'phone': '+12813625999',
#   'display_phone': '(281) 362-5999',
#   'distance': 11332.323946841785},
#  {'id': 'yzrodWZKrj-08srAf4OsZQ',
#   'alias': 'amaravati-indian-cuisine-spring',
#   'name': 'Amaravati Indian cuisine',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/MUHJnyHADeVuLkCBsJERmA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/amaravati-indian-cuisine-spring?adjust_creative=tKntTkL12un_MRxa4uShMA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=tKntTkL12un_MRxa4uShMA',
#   'review_count': 74,
#   'categories': [{'alias': 'indpak', 'title': 'Indian'},
#    {'alias': 'halal', 'title': 'Halal'},
#    {'alias': 'buffets', 'title': 'Buffets'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 30.12748, 'longitude': -95.4466},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '202 Sawdust Rd',
#    'address2': 'Ste 115',
#    'address3': '',
#    'city': 'Spring',
#    'zip_code': '77380',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['202 Sawdust Rd', 'Ste 115', 'Spring, TX 77380']},
#   'phone': '+12812985570',
#   'display_phone': '(281) 298-5570',
#   'distance': 5304.121097502602},
#  {'id': 'omjrH6c1cMraGOPpCwBjnA',
#   'alias': 'sitar-cuisine-of-india-spring-2',
#   'name': 'Sitar Cuisine of India',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/kigMXz5f4E--1NLDpzKhsg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sitar-cuisine-of-india-spring-2?adjust_creative=tKntTkL12un_MRxa4uShMA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=tKntTkL12un_MRxa4uShMA',
#   'review_count': 209,
#   'categories': [{'alias': 'indpak', 'title': 'Indian'},
#    {'alias': 'vegetarian', 'title': 'Vegetarian'},
#    {'alias': 'vegan', 'title': 'Vegan'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 30.1359867579162,
#    'longitude': -95.4460223767212},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '25701 Interstate 45',
#    'address2': None,
#    'address3': '',
#    'city': 'Spring',
#    'zip_code': '77380',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['25701 Interstate 45', 'Spring, TX 77380']},
#   'phone': '+12813640200',
#   'display_phone': '(281) 364-0200',
#   'distance': 4679.110236566684},
#  {'id': 'syCPmHGT0j4liqB9VH7u2w',
#   'alias': 'flower-child-the-woodlands-2',
#   'name': 'Flower Child',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/E5Na6B69e9L6kGkRRfyz0Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/flower-child-the-woodlands-2?adjust_creative=tKntTkL12un_MRxa4uShMA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=tKntTkL12un_MRxa4uShMA',
#   'review_count': 63,
#   'categories': [{'alias': 'salad', 'title': 'Salad'},
#    {'alias': 'vegetarian', 'title': 'Vegetarian'},
#    {'alias': 'newamerican', 'title': 'American (New)'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 30.165429, 'longitude': -95.4633475},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '1900 Lake Woodlands Dr',
#    'address2': 'Ste 100',
#    'address3': None,
#    'city': 'The Woodlands',
#    'zip_code': '77380',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['1900 Lake Woodlands Dr',
#     'Ste 100',
#     'The Woodlands, TX 77380']},
#   'phone': '+13462687101',
#   'display_phone': '(346) 268-7101',
#   'distance': 1868.7217966674202},
#  {'id': 'n0QAyDSkBqEY2uTuASTDQw',
#   'alias': 'tandoori-indian-cuisine-spring-2',
#   'name': 'Tandoori Indian Cuisine',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6yiWyhpGXgsQHEbA6CPAJQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tandoori-indian-cuisine-spring-2?adjust_creative=tKntTkL12un_MRxa4uShMA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=tKntTkL12un_MRxa4uShMA',
#   'review_count': 104,
#   'categories': [{'alias': 'indpak', 'title': 'Indian'},
#    {'alias': 'pakistani', 'title': 'Pakistani'},
#    {'alias': 'bangladeshi', 'title': 'Bangladeshi'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 30.074516, 'longitude': -95.498442},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '5200 Fm 2920',
#    'address2': 'Ste 120',
#    'address3': '',
#    'city': 'Spring',
#    'zip_code': '77388',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['5200 Fm 2920', 'Ste 120', 'Spring, TX 77388']},
#   'phone': '+12814662678',
#   'display_phone': '(281) 466-2678',
#   'distance': 10047.456346137698},
#  {'id': 'LuZM6MNt2SH7Ue1LDfQKqw',
#   'alias': 'tarka-indian-kitchen-spring',
#   'name': 'Tarka Indian Kitchen',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YvLQunaHVWwPXAiXBhdSLA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tarka-indian-kitchen-spring?adjust_creative=tKntTkL12un_MRxa4uShMA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=tKntTkL12un_MRxa4uShMA',
#   'review_count': 107,
#   'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 30.084808, 'longitude': -95.449789},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '2168 Spring Stuebner Rd',
#    'address2': 'Ste 290',
#    'address3': '',
#    'city': 'Spring',
#    'zip_code': '77373',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['2168 Spring Stuebner Rd',
#     'Ste 290',
#     'Spring, TX 77373']},
#   'phone': '+13462248124',
#   'display_phone': '(346) 224-8124',
#   'distance': 9332.63937518506},
#  {'id': 'RZTDCsCPw2HjlHZyx7g0pA',
#   'alias': 'zaras-mediterranean-kitchen-spring-5',
#   'name': "Zara's Mediterranean Kitchen",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/NgB0T-tvvRRvdy5u_4teag/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/zaras-mediterranean-kitchen-spring-5?adjust_creative=tKntTkL12un_MRxa4uShMA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=tKntTkL12un_MRxa4uShMA',
#   'review_count': 420,
#   'categories': [{'alias': 'halal', 'title': 'Halal'},
#    {'alias': 'mediterranean', 'title': 'Mediterranean'},
#    {'alias': 'greek', 'title': 'Greek'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 30.1277798, 'longitude': -95.4364679},
#   'transactions': ['pickup'],
#   'price': '$$',
#   'location': {'address1': '415 Rayford Rd',
#    'address2': 'Ste 300',
#    'address3': '',
#    'city': 'Spring',
#    'zip_code': '77386',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['415 Rayford Rd', 'Ste 300', 'Spring, TX 77386']},
#   'phone': '+17135759272',
#   'display_phone': '(713) 575-9272',
#   'distance': 5972.357431267424},
#  {'id': 'HlzmenzKloPWIsWtxzmEIA',
#   'alias': 'aroma-coffee-bar-the-woodlands',
#   'name': 'Aroma Coffee Bar',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Ag84i9wnljeJsCvu1oiXPA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/aroma-coffee-bar-the-woodlands?adjust_creative=tKntTkL12un_MRxa4uShMA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=tKntTkL12un_MRxa4uShMA',
#   'review_count': 7,
#   'categories': [{'alias': 'indpak', 'title': 'Indian'},
#    {'alias': 'cafes', 'title': 'Cafes'}],
#   'rating': 2.5,
#   'coordinates': {'latitude': 30.1657962799072,
#    'longitude': -95.4542770385742},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '1201 Lake Woodlands Dr',
#    'address2': '',
#    'address3': None,
#    'city': 'The Woodlands',
#    'zip_code': '77380',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['1201 Lake Woodlands Dr', 'The Woodlands, TX 77380']},
#   'phone': '+12813633409',
#   'display_phone': '(281) 363-3409',
#   'distance': 2759.4389420765337},
#  {'id': 'g8AyYGBRmHHcgFI59GH8VA',
#   'alias': 'woodlands-desi-grocery-and-halal-market-conroe-2',
#   'name': 'Woodlands Desi Grocery and Halal Market',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/q0K6swgm1sQJ9YjWdiH_Dg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/woodlands-desi-grocery-and-halal-market-conroe-2?adjust_creative=tKntTkL12un_MRxa4uShMA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=tKntTkL12un_MRxa4uShMA',
#   'review_count': 4,
#   'categories': [{'alias': 'halal', 'title': 'Halal'},
#    {'alias': 'intlgrocery', 'title': 'International Grocery'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 30.2077793356892,
#    'longitude': -95.4448175697073},
#   'transactions': [],
#   'location': {'address1': '8546 Texas 242 Access Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Conroe',
#    'zip_code': '77385',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['8546 Texas 242 Access Rd', 'Conroe, TX 77385']},
#   'phone': '+19362735808',
#   'display_phone': '(936) 273-5808',
#   'distance': 6084.943009864656}]

# %%
response.json()['total']
# Out:
# 11

# %% [markdown]
# ## Exploratory Analysis
#
# Take the restaurants from the previous question and do an intial exploratory analysis. At minimum, this should include looking at the distribution of features such as price, rating and number of reviews as well as the relations between these dimensions.

# %%
#Your code here
import pandas as pd

df = pd.DataFrame.from_dict(response.json()['businesses'])
print(len(df)) #Print how many rows
print(df.columns) #Print column names
df #Previews the first five rows. 
#You could also write df.head(10) to preview 10 rows or df.tail() to see the bottom
# Out:
# 10
# Index(['alias', 'categories', 'coordinates', 'display_phone', 'distance', 'id',
#        'image_url', 'is_closed', 'location', 'name', 'phone', 'price',
#        'rating', 'review_count', 'transactions', 'url'],
#       dtype='object')
#                                               alias  \
# 0                     hyderabad-house-the-woodlands
# 1                     palette-indian-kitchen-spring
# 2                   amaravati-indian-cuisine-spring
# 3                   sitar-cuisine-of-india-spring-2
# 4                      flower-child-the-woodlands-2
# 5                  tandoori-indian-cuisine-spring-2
# 6                       tarka-indian-kitchen-spring
# 7              zaras-mediterranean-kitchen-spring-5
# 8                    aroma-coffee-bar-the-woodlands
# 9  woodlands-desi-grocery-and-halal-market-conroe-2
#
#                                           categories  \
# 0           [{'alias': 'indpak', 'title': 'Indian'}]
# 1           [{'alias': 'indpak', 'title': 'Indian'}]
# 2  [{'alias': 'indpak', 'title': 'Indian'}, {'ali...
# 3  [{'alias': 'indpak', 'title': 'Indian'}, {'ali...
# 4  [{'alias': 'salad', 'title': 'Salad'}, {'alias...
# 5  [{'alias': 'indpak', 'title': 'Indian'}, {'ali...
# 6           [{'alias': 'indpak', 'title': 'Indian'}]
# 7  [{'alias': 'halal', 'title': 'Halal'}, {'alias...
# 8  [{'alias': 'indpak', 'title': 'Indian'}, {'ali...
# 9  [{'alias': 'halal', 'title': 'Halal'}, {'alias...
#
#                                          coordinates   display_phone  \
# 0  {'latitude': 30.1265751, 'longitude': -95.4480...  (281) 203-5020
# 1  {'latitude': 30.1076513, 'longitude': -95.3851...  (281) 362-5999
# 2      {'latitude': 30.12748, 'longitude': -95.4466}  (281) 298-5570
# 3  {'latitude': 30.1359867579162, 'longitude': -9...  (281) 364-0200
# 4  {'latitude': 30.165429, 'longitude': -95.4633475}  (346) 268-7101
# 5   {'latitude': 30.074516, 'longitude': -95.498442}  (281) 466-2678
# 6   {'latitude': 30.084808, 'longitude': -95.449789}  (346) 224-8124
# 7  {'latitude': 30.1277798, 'longitude': -95.4364...  (713) 575-9272
# 8  {'latitude': 30.1657962799072, 'longitude': -9...  (281) 363-3409
# 9  {'latitude': 30.2077793356892, 'longitude': -9...  (936) 273-5808
#
#        distance                      id  \
# 0   5554.975358  CoIm7M7QaPHXEs5LpjH06g
# 1  11332.323947  yGc0I0S-MHZtspmlW8b2hQ
# 2   5304.121098  yzrodWZKrj-08srAf4OsZQ
# 3   4679.110237  omjrH6c1cMraGOPpCwBjnA
# 4   1868.721797  syCPmHGT0j4liqB9VH7u2w
# 5  10047.456346  n0QAyDSkBqEY2uTuASTDQw
# 6   9332.639375  LuZM6MNt2SH7Ue1LDfQKqw
# 7   5972.357431  RZTDCsCPw2HjlHZyx7g0pA
# 8   2759.438942  HlzmenzKloPWIsWtxzmEIA
# 9   6084.943010  g8AyYGBRmHHcgFI59GH8VA
#
#                                            image_url  is_closed  \
# 0  https://s3-media2.fl.yelpcdn.com/bphoto/fD-P7G...      False
# 1  https://s3-media3.fl.yelpcdn.com/bphoto/qm4Cs-...      False
# 2  https://s3-media4.fl.yelpcdn.com/bphoto/MUHJny...      False
# 3  https://s3-media1.fl.yelpcdn.com/bphoto/kigMXz...      False
# 4  https://s3-media2.fl.yelpcdn.com/bphoto/E5Na6B...      False
# 5  https://s3-media3.fl.yelpcdn.com/bphoto/6yiWyh...      False
# 6  https://s3-media2.fl.yelpcdn.com/bphoto/YvLQun...      False
# 7  https://s3-media1.fl.yelpcdn.com/bphoto/NgB0T-...      False
# 8  https://s3-media1.fl.yelpcdn.com/bphoto/Ag84i9...      False
# 9  https://s3-media1.fl.yelpcdn.com/bphoto/q0K6sw...      False
#
#                                             location  \
# 0  {'address1': '407 Sawdust Rd', 'address2': Non...
# 1  {'address1': '3559 Rayford Rd', 'address2': 'S...
# 2  {'address1': '202 Sawdust Rd', 'address2': 'St...
# 3  {'address1': '25701 Interstate 45', 'address2'...
# 4  {'address1': '1900 Lake Woodlands Dr', 'addres...
# 5  {'address1': '5200 Fm 2920', 'address2': 'Ste ...
# 6  {'address1': '2168 Spring Stuebner Rd', 'addre...
# 7  {'address1': '415 Rayford Rd', 'address2': 'St...
# 8  {'address1': '1201 Lake Woodlands Dr', 'addres...
# 9  {'address1': '8546 Texas 242 Access Rd', 'addr...
#
#                                       name         phone price  rating  \
# 0                          Hyderabad House  +12812035020    $$     3.5
# 1                   Palette Indian Kitchen  +12813625999    $$     4.5
# 2                 Amaravati Indian cuisine  +12812985570    $$     4.0
# 3                   Sitar Cuisine of India  +12813640200    $$     3.5
# 4                             Flower Child  +13462687101    $$     4.0
# 5                  Tandoori Indian Cuisine  +12814662678    $$     4.0
# 6                     Tarka Indian Kitchen  +13462248124    $$     4.0
# 7             Zara's Mediterranean Kitchen  +17135759272    $$     4.5
# 8                         Aroma Coffee Bar  +12813633409     $     2.5
# 9  Woodlands Desi Grocery and Halal Market  +19362735808   NaN     3.0
#
#    review_count        transactions  \
# 0           162  [delivery, pickup]
# 1           247                  []
# 2            74  [delivery, pickup]
# 3           209  [delivery, pickup]
# 4            63                  []
# 5           104  [delivery, pickup]
# 6           107  [delivery, pickup]
# 7           420            [pickup]
# 8             7                  []
# 9             4                  []
#
#                                                  url
# 0  https://www.yelp.com/biz/hyderabad-house-the-w...
# 1  https://www.yelp.com/biz/palette-indian-kitche...
# 2  https://www.yelp.com/biz/amaravati-indian-cuis...
# 3  https://www.yelp.com/biz/sitar-cuisine-of-indi...
# 4  https://www.yelp.com/biz/flower-child-the-wood...
# 5  https://www.yelp.com/biz/tandoori-indian-cuisi...
# 6  https://www.yelp.com/biz/tarka-indian-kitchen-...
# 7  https://www.yelp.com/biz/zaras-mediterranean-k...
# 8  https://www.yelp.com/biz/aroma-coffee-bar-the-...
# 9  https://www.yelp.com/biz/woodlands-desi-grocer...

# %%
import matplotlib.pyplot as plt
plt.scatter(df['review_count'],df['rating'])
plt.xlabel('Number of Reviews')
plt.ylabel('Average Rating')
# Out:
# Text(0, 0.5, 'Average Rating')

# %% [markdown]
# ## Mapping
#
# Look at the initial Yelp example and try and make a map using Folium of the restaurants you retrieved. Be sure to also add popups to the markers giving some basic information such as name, rating and price.

# %%
#Your code here
import folium

lat_long = df['coordinates'].iloc[0]
lat = lat_long['latitude']
long = lat_long['longitude']
yelp_map = folium.Map([lat, long])

for row in df.index:
    try:
        lat_long = df['coordinates'][row]
        lat = lat_long['latitude']
        long = lat_long['longitude']
        name = df['name'][row]
        rating = df['rating'][row]
        price = df['price'][row]
        details = "{}\nPrice: {} Rating:{}".format(name,str(price),str(rating))
        popup = folium.Popup(details, parse_html=True)
        marker = folium.Marker([lat, long], popup=popup)
        marker.add_to(yelp_map)
    except:
        print('Hit error on row: {}'.format(row))
yelp_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Summary
#
# Nice work! In this lab, you synthesized your skills for the day, making multiple API calls to Yelp in order to paginate through a results set, performing some basic exploratory analysis and then creating a nice map visual to display the results! Well done!
